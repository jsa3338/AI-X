# %%
import json
with open('data/한국토지주택공사_남양주왕숙2 토지이용계획도_20210924.json', encoding='utf-8') as f:
        load_data = json.load(f)
load_data
# Out:
# {'image': {'mime': 'image/jpeg',
#   'data': '...'}}
