# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # 1. 환경변수 로드

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# ## 2.1 openAI SDK 를 선택

# %%
# pip install openai
import os
from openai import OpenAI # openai==1.52.2
upstage_api_key = os.getenv("UPSTAGE_API_KEY")
client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)
 
stream = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {
            "role": "user",
            "content": "2020년 월드시리즈 누가 우승했어?"
        }
    ],
    stream=False,
)
 
print(stream.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 **로스앤젤레스 다저스**가 **탬파베이 레이스**를 4승 2패로 누르고 우승했습니다.
#
# - **시리즈 결과**: 다저스 4승 vs 레이스 2패
# - **MVP**: 다저스의 투수 **코리 시거**(Corey Seager)가 시리즈 MVP로 선정되었습니다.
# - **특이사항**: 코로나19 팬데믹 영향으로 무관중 경기로 진행되었으며, 6경기로 단축된 플레이오프 형식이 적용되었습니다.
#
# 다저스는 1988년 이후 32년 만에 통산 28번째 월드시리즈 우승을 달성했습니다.

# %%
stream
# Out:
# ChatCompletion(id='b0d9f8c8-a69f-4170-9397-decdca8e7f1a', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='2020년 월드시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다.  \n\n- **상대 팀**: 탬파베이 레이스  \n- **시리즈 결과**: 4승 2패로 다저스 승리  \n- **MVP**: 다저스의 투수 **클레이턴 커쇼** (비록 MVP는 아니었으나, 핵심 활약을 했으며, 공식 MVP는 다저스의 유격수 **코어리 시거**가 수상했습니다.)  \n\n2020년 시즌은 코로나19 팬데믹의 영향으로 특별히 짧은 일정으로 진행되었으며, 월드시리즈는 10월 1일부터 31일까지 열렸습니다. 다저스는 프랭크 윌리암스 구단주 시대에 첫 번째 월드시리즈 우승을 달성했습니다.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1753767224, model='solar-pro2-250710', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=159, prompt_tokens=26, total_tokens=185, completion_tokens_details=None, prompt_tokens_details=None))

# %% [markdown]
# ## 2.2 LangChain을 선택
# - 발급받은 API Key를 .env에 UPSTAGE_API_KEY라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content="You are a kind and smart assistant"),
    HumanMessage(content="2020년 월드 시리즈 누가 우승했어")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드 시리즈 우승을 차지했습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 33, 'total_tokens': 80, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': 'df35f5e4-cf1d-4061-b5a4-1db1e20f0294', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--9d6bf1b0-5541-4dd7-a278-7bc469530872-0', usage_metadata={'input_tokens': 33, 'output_tokens': 47, 'total_tokens': 80, 'input_token_details': {}, 'output_token_details': {}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 32년 만에 월드 시리즈 우승을 차지했습니다.'
