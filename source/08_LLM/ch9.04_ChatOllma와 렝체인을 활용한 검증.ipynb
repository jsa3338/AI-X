# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
# %pip install -q langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 1. 환경변수 설정

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM 답변 생성
# - https://ollama.com/ 에서 모델 선택(
# - 파워쉘이나 명령프롬프트에서 ollama pull llama3.2:1b

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
ai_message = llm.invoke("2020년 월드시리즈에서 누가 우승했어?")
ai_message
# Out:
# AIMessage(content='2020 년 월드 시리즈는 아ิต라니아 섬에서 열렸습니다. 이 경기로 가장 유명한 월드 시리즈는 2019 년 actually의 "월드 시리즈"라는 이름으로 알려진 "아시아 월드 시리즈"가 있습니다. \n\n이 Jahre 2세기 월드 시리즈는 2020 년 8 월 28 일부터 10 월 11 일까지 열렸습니다. 이 시즌은 1 분간에 3 구를 나눔에 따라 우승할 수 있도록 wasabi 마일스 및 nongame\'s 자체 경쟁인 "유니버설 sports"의 도움이 đỡ으로 2 번씩 시작되었습니다.\n\n이 Jahre의 우승은 wasabi 마일스입니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-07-29T05:56:51.7954125Z', 'done': True, 'done_reason': 'stop', 'total_duration': 14989040500, 'load_duration': 2858964300, 'prompt_eval_count': 40, 'prompt_eval_duration': 642937900, 'eval_count': 165, 'eval_duration': 11481672300, 'model_name': 'llama3.2:1b'}, id='run--309ff2ea-8ac0-47d4-af7a-6d73b8eb8ea2-0', usage_metadata={'input_tokens': 40, 'output_tokens': 165, 'total_tokens': 205})

# %% [markdown]
# # 3. 코랩에서 ollama(exaone3.5:2.4b) 돌리기
# - http://bit.ly/3IKpnVH
